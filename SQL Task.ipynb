# %%
import sqlite3
import pandas as pd

# %%
# Load CSV
df = pd.read_csv("downloads/cybersecurity_threat_dataset.csv")

# Create SQLite database
conn = sqlite3.connect("cyber_threats.db")

# Load DataFrame into SQL table
df.to_sql("cyber_threats", conn, if_exists="replace", index=False)

print("Dataset loaded into SQLite database.")
# Out:
# Dataset loaded into SQLite database.

# %%
query = "SELECT * FROM cyber_threats LIMIT 5;"
pd.read_sql(query, conn)
# Out:
#   incident_id            timestamp attack_type attack_vector  severity  \
# 0     INC0001  2026-01-05 00:27:05     Malware           USB       Low
# 1     INC0002  2025-12-26 05:18:05     Malware         Email  Critical
# 2     INC0003  2025-12-12 20:46:05        DDoS           USB       Low
# 3     INC0004  2025-12-28 00:37:05        DDoS           Web      High
# 4     INC0005  2026-01-02 09:14:05  Ransomware         Email       Low
#
#   source_country target_country        source_ip device_affected  \
# 0      Australia         Brazil   171.127.95.117        Firewall
# 1          China        Germany     194.146.3.19          Mobile
# 2      Australia          India  156.224.186.234          Server
# 3          China      Australia    110.16.33.198          Router
# 4      Australia             UK   193.118.71.152         Desktop
#
#   operating_system       target_system protocol  port      status detected_by  \
# 0          Windows            Cloud VM      TCP    25     Blocked        SIEM
# 1            macOS            Database    HTTPS   443      Failed         IDS
# 2              iOS            Database      TCP    25  Successful         IPS
# 3          Android          IoT Device      UDP    80   Mitigated         IDS
# 4              iOS  Application Server     HTTP  8080      Failed        SIEM
#
#   impact_level mitigation_action
# 0          Low     Patch Applied
# 1       Severe     Patch Applied
# 2       Severe   System Isolated
# 3       Severe      User Alerted
# 4     Critical   System Isolated

# %%
query = "SELECT * FROM cyber_threats;"
pd.read_sql(query, conn).head()
# Out:
#   incident_id            timestamp attack_type attack_vector  severity  \
# 0     INC0001  2026-01-05 00:27:05     Malware           USB       Low
# 1     INC0002  2025-12-26 05:18:05     Malware         Email  Critical
# 2     INC0003  2025-12-12 20:46:05        DDoS           USB       Low
# 3     INC0004  2025-12-28 00:37:05        DDoS           Web      High
# 4     INC0005  2026-01-02 09:14:05  Ransomware         Email       Low
#
#   source_country target_country        source_ip device_affected  \
# 0      Australia         Brazil   171.127.95.117        Firewall
# 1          China        Germany     194.146.3.19          Mobile
# 2      Australia          India  156.224.186.234          Server
# 3          China      Australia    110.16.33.198          Router
# 4      Australia             UK   193.118.71.152         Desktop
#
#   operating_system       target_system protocol  port      status detected_by  \
# 0          Windows            Cloud VM      TCP    25     Blocked        SIEM
# 1            macOS            Database    HTTPS   443      Failed         IDS
# 2              iOS            Database      TCP    25  Successful         IPS
# 3          Android          IoT Device      UDP    80   Mitigated         IDS
# 4              iOS  Application Server     HTTP  8080      Failed        SIEM
#
#   impact_level mitigation_action
# 0          Low     Patch Applied
# 1       Severe     Patch Applied
# 2       Severe   System Isolated
# 3       Severe      User Alerted
# 4     Critical   System Isolated

# %%
query = "SELECT COUNT(*) AS total_attacks FROM cyber_threats;"
pd.read_sql(query, conn)
# Out:
#    total_attacks
# 0            320

# %%
query = """
SELECT attack_type, COUNT(*) AS attack_count
FROM cyber_threats
GROUP BY attack_type
ORDER BY attack_count DESC;
"""
pd.read_sql(query, conn)
# Out:
#      attack_type  attack_count
# 0        Malware            61
# 1     Ransomware            58
# 2       Phishing            58
# 3           DDoS            56
# 4    Brute Force            45
# 5  SQL Injection            42

# %%
query = """
SELECT severity, COUNT(*) AS count
FROM cyber_threats
GROUP BY severity;
"""
pd.read_sql(query, conn)
# Out:
#    severity  count
# 0  Critical     82
# 1      High     77
# 2       Low     67
# 3    Medium     94

# %%
query = """
SELECT *
FROM cyber_threats
WHERE severity = 'High';
"""
pd.read_sql(query, conn).head()
# Out:
#   incident_id            timestamp attack_type attack_vector severity  \
# 0     INC0004  2025-12-28 00:37:05        DDoS           Web     High
# 1     INC0009  2025-12-03 13:16:05     Malware           Web     High
# 2     INC0014  2025-12-25 22:18:05  Ransomware       Network     High
# 3     INC0015  2026-01-02 20:42:05     Malware         Email     High
# 4     INC0017  2026-01-04 04:48:05  Ransomware         Cloud     High
#
#   source_country target_country       source_ip device_affected  \
# 0          China      Australia   110.16.33.198          Router
# 1        Germany         Brazil  97.215.135.150          Server
# 2          China      Australia    29.57.224.36          Server
# 3          China      Australia   74.86.120.179          Router
# 4         France             UK  164.137.70.142          Server
#
#   operating_system       target_system protocol  port      status detected_by  \
# 0          Android          IoT Device      UDP    80   Mitigated         IDS
# 1              iOS          Web Server     HTTP  8080      Failed        SIEM
# 2          Android            Cloud VM      TCP   443  Successful    Firewall
# 3            macOS          Web Server     HTTP    80     Blocked   Antivirus
# 4            macOS  Application Server     HTTP    21   Mitigated         IPS
#
#   impact_level mitigation_action
# 0       Severe      User Alerted
# 1     Moderate   System Isolated
# 2       Severe   System Isolated
# 3     Critical  Traffic Filtered
# 4     Moderate        IP Blocked

# %%
query = """
SELECT source_country, COUNT(*) AS total_attacks
FROM cyber_threats
GROUP BY source_country
ORDER BY total_attacks DESC;
"""
pd.read_sql(query, conn)
# Out:
#   source_country  total_attacks
# 0         France             45
# 1          China             43
# 2        Germany             39
# 3         Russia             36
# 4          India             36
# 5      Australia             35
# 6            USA             33
# 7         Brazil             27
# 8             UK             26

# %%
query = """
SELECT device_affected, COUNT(*) AS attack_count
FROM cyber_threats
GROUP BY device_affected
ORDER BY attack_count DESC;
"""
pd.read_sql(query, conn)
# Out:
#   device_affected  attack_count
# 0          Router            65
# 1          Server            60
# 2          Mobile            52
# 3          Laptop            50
# 4        Firewall            48
# 5         Desktop            45

# %%
query = """
SELECT status, COUNT(*) AS count
FROM cyber_threats
GROUP BY status;
"""
pd.read_sql(query, conn)
# Out:
#        status  count
# 0     Blocked     75
# 1      Failed     84
# 2   Mitigated     89
# 3  Successful     72

# %%
query = """
SELECT target_system, COUNT(*) AS count
FROM cyber_threats
GROUP BY target_system
ORDER BY count DESC
LIMIT 10;
"""
pd.read_sql(query, conn)
# Out:
#         target_system  count
# 0          Web Server     75
# 1            Database     67
# 2            Cloud VM     62
# 3  Application Server     62
# 4          IoT Device     54

# %%
query = """
SELECT AVG(impact_level) AS avg_impact
FROM cyber_threats;
"""
pd.read_sql(query, conn)
# Out:
#    avg_impact
# 0         0.0

# %%
query = "PRAGMA table_info(cyber_threats);"
pd.read_sql(query, conn)
# Out:
#     cid               name     type  notnull dflt_value  pk
# 0     0        incident_id     TEXT        0       None   0
# 1     1          timestamp     TEXT        0       None   0
# 2     2        attack_type     TEXT        0       None   0
# 3     3      attack_vector     TEXT        0       None   0
# 4     4           severity     TEXT        0       None   0
# 5     5     source_country     TEXT        0       None   0
# 6     6     target_country     TEXT        0       None   0
# 7     7          source_ip     TEXT        0       None   0
# 8     8    device_affected     TEXT        0       None   0
# 9     9   operating_system     TEXT        0       None   0
# 10   10      target_system     TEXT        0       None   0
# 11   11           protocol     TEXT        0       None   0
# 12   12               port  INTEGER        0       None   0
# 13   13             status     TEXT        0       None   0
# 14   14        detected_by     TEXT        0       None   0
# 15   15       impact_level     TEXT        0       None   0
# 16   16  mitigation_action     TEXT        0       None   0

# %%
query = "SELECT DISTINCT impact_level FROM cyber_threats;"
pd.read_sql(query, conn)
# Out:
#   impact_level
# 0          Low
# 1       Severe
# 2     Critical
# 3     Moderate

# %%
impact_mapping = {
    "Low": 1,
    "Medium": 2,
    "High": 3,
    "Critical": 4
}

df['impact_level_numeric'] = df['impact_level'].map(impact_mapping)

# %%
df.to_sql("cyber_threats", conn, if_exists="replace", index=False)
# Out:
# 320

# %%
query = """
SELECT AVG(impact_level_numeric) AS avg_impact
FROM cyber_threats;
"""
pd.read_sql(query, conn)
# Out:
#    avg_impact
# 0     2.30814

# %%
query = """
SELECT attack_type, AVG(impact_level_numeric) AS avg_impact
FROM cyber_threats
GROUP BY attack_type
HAVING AVG(impact_level_numeric) > (
    SELECT AVG(impact_level_numeric) FROM cyber_threats
);
"""
pd.read_sql(query, conn)
# Out:
#   attack_type  avg_impact
# 0        DDoS    2.457143
# 1     Malware    2.390244
# 2    Phishing    2.500000
# 3  Ransomware    2.434783

# %%
query = """
SELECT attack_type, COUNT(*) AS total_attacks
FROM cyber_threats
GROUP BY attack_type
ORDER BY total_attacks DESC
LIMIT 5;
"""
pd.read_sql(query, conn)
# Out:
#    attack_type  total_attacks
# 0      Malware             61
# 1   Ransomware             58
# 2     Phishing             58
# 3         DDoS             56
# 4  Brute Force             45

# %%
query = """
SELECT source_country, COUNT(*) AS high_severity_attacks
FROM cyber_threats
WHERE severity = 'High'
GROUP BY source_country
ORDER BY high_severity_attacks DESC;
"""
pd.read_sql(query, conn)
# Out:
#   source_country  high_severity_attacks
# 0         France                     11
# 1         Russia                     10
# 2          China                     10
# 3            USA                      9
# 4             UK                      9
# 5          India                      8
# 6        Germany                      7
# 7      Australia                      7
# 8         Brazil                      6

# %%
query = """
SELECT device_affected, attack_type, COUNT(*) AS attack_count
FROM cyber_threats
GROUP BY device_affected, attack_type
ORDER BY attack_count DESC;
"""
pd.read_sql(query, conn)
# Out:
#    device_affected    attack_type  attack_count
# 0           Router        Malware            14
# 1          Desktop     Ransomware            12
# 2           Mobile        Malware            12
# 3           Router           DDoS            12
# 4           Server    Brute Force            12
# 5         Firewall       Phishing            11
# 6         Firewall     Ransomware            11
# 7           Mobile    Brute Force            11
# 8           Router       Phishing            11
# 9           Router  SQL Injection            11
# 10          Server           DDoS            11
# 11          Server       Phishing            11
# 12          Server     Ransomware            11
# 13          Laptop           DDoS            10
# 14          Router     Ransomware            10
# 15         Desktop        Malware             9
# 16        Firewall           DDoS             9
# 17        Firewall        Malware             9
# 18          Laptop       Phishing             9
# 19          Server        Malware             9
# 20         Desktop       Phishing             8
# 21          Laptop    Brute Force             8
# 22          Laptop        Malware             8
# 23          Laptop  SQL Injection             8
# 24          Mobile           DDoS             8
# 25          Mobile       Phishing             8
# 26          Laptop     Ransomware             7
# 27          Mobile     Ransomware             7
# 28          Router    Brute Force             7
# 29         Desktop           DDoS             6
# 30        Firewall  SQL Injection             6
# 31          Mobile  SQL Injection             6
# 32          Server  SQL Injection             6
# 33         Desktop    Brute Force             5
# 34         Desktop  SQL Injection             5
# 35        Firewall    Brute Force             2

# %%
query = """
SELECT detected_by, COUNT(*) AS detected_attacks
FROM cyber_threats
GROUP BY detected_by
ORDER BY detected_attacks DESC;
"""
pd.read_sql(query, conn)
# Out:
#   detected_by  detected_attacks
# 0        SIEM                68
# 1         IDS                67
# 2    Firewall                63
# 3         IPS                61
# 4   Antivirus                61

# %%
query = """
SELECT attack_type, ROUND(AVG(impact_level_numeric), 2) AS avg_impact
FROM cyber_threats
GROUP BY attack_type
ORDER BY avg_impact DESC;
"""
pd.read_sql(query, conn)
# Out:
#      attack_type  avg_impact
# 0       Phishing        2.50
# 1           DDoS        2.46
# 2     Ransomware        2.43
# 3        Malware        2.39
# 4    Brute Force        2.00
# 5  SQL Injection        1.88

# %%
query = """
SELECT operating_system, COUNT(*) AS total_attacks
FROM cyber_threats
GROUP BY operating_system
ORDER BY total_attacks DESC;
"""
pd.read_sql(query, conn)
# Out:
#   operating_system  total_attacks
# 0          Windows             72
# 1            macOS             70
# 2          Android             64
# 3              iOS             62
# 4            Linux             52

# %%
query = """
SELECT status, COUNT(*) AS count
FROM cyber_threats
GROUP BY status;
"""
pd.read_sql(query, conn)
# Out:
#        status  count
# 0     Blocked     75
# 1      Failed     84
# 2   Mitigated     89
# 3  Successful     72
